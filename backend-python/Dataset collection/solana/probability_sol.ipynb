# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
from io import StringIO

# %%
data = pd.read_csv('solSentiment.csv')
data
# Out:
#                     Unnamed: 0        open        high         low  \
# 0    2021-12-02 00:00:00+00:00  229.854706  243.111664  220.387177
# 1    2021-12-06 00:00:00+00:00  196.547485  197.663025  176.888062
# 2    2021-12-08 00:00:00+00:00  190.505005  196.374115  184.132706
# 3    2021-12-09 00:00:00+00:00  194.483292  196.689743  178.792145
# 4    2021-12-13 00:00:00+00:00  173.099930  173.099930  148.571823
# ..                         ...         ...         ...         ...
# 156  2024-02-19 00:00:00+00:00  112.178825  114.717979  111.081413
# 157  2024-02-20 00:00:00+00:00  111.483444  112.036743  104.890228
# 158  2024-02-21 00:00:00+00:00  108.452667  108.452667  100.412018
# 159  2024-03-14 00:00:00+00:00  163.839935  177.892624  160.233551
# 160  2024-03-17 00:00:00+00:00  181.880341  204.292542  179.225601
#
#           close       volume  edit_count  sentiment  neg_sentiment  \
# 0    233.993042   4074103518    2.466667  -0.115112       0.526768
# 1    194.199219   3693853028    2.433333  -0.147124       0.543434
# 2    194.621704   2277446203    2.400000  -0.176140       0.560101
# 3    181.178085   1968182104    2.466667  -0.215607       0.582323
# 4    155.213058   2547597256    2.533333  -0.234919       0.593434
# ..          ...          ...         ...        ...            ...
# 156  111.485329   1898655220    2.933333  -0.214769       0.604246
# 157  108.459641   2656976089    3.100000  -0.202918       0.598690
# 158  105.125221   2246861647    3.166667  -0.180640       0.587579
# 159  176.679749   8399967972    3.133333  -0.147472       0.570913
# 160  202.123566  10876218562    2.900000  -0.156470       0.575079
#
#        tomorrow  target
# 0    194.199219       0
# 1    194.621704       1
# 2    181.178085       0
# 3    155.213058       0
# 4    153.341446       0
# ..          ...     ...
# 156  108.459641       0
# 157  105.125221       0
# 158  176.679749       1
# 159  202.123566       1
# 160         NaN       0
#
# [161 rows x 11 columns]

# %%
features = ['open', 'high', 'low', 'close', 'volume', 'edit_count', 'sentiment', 'neg_sentiment']
target = 'target'

X = data[features]
y = data[target]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Accuracy: 0.5151515151515151
# Confusion Matrix:
# [[ 8  3]
#  [13  9]]

# %%
import pandas as pd

# Read the CSV file
data_from_sol = pd.read_csv("sol.csv")

# Get the last row
last_row_sol = data_from_sol.iloc[-1]

print("Last row from sol.csv:")
print(last_row_sol)
# Out:
# Last row from sol.csv:
# Date            2024-06-03 00:00:00+00:00
# Open                           163.218658
# High                           165.460602
# Low                            161.855103
# Close                          165.418304
# Volume                         1816263936
# Dividends                             0.0
# Stock Splits                          0.0
# Name: 1515, dtype: object

# %%
import pandas as pd

# Read the CSV file for sentiment data related to 'sol'
sentiment_from_sol = pd.read_csv("solana_sentiment.csv")

# Get the last row
last_row_sol_sentiment = sentiment_from_sol.iloc[-1]

print("Last row from solana_sentiment.csv:")
print(last_row_sol_sentiment)
# Out:
# Last row from solana_sentiment.csv:
# Unnamed: 0       2024-03-17
# edit_count              2.9
# sentiment          -0.15647
# neg_sentiment      0.575079
# Name: 160, dtype: object

# %%
# Function to fetch the latest data for Sol
def fetch_latest_data():
    # This function should fetch the latest data from your real-time source
    latest_data = {
        "open": last_row_sol['Open'],
        "high": last_row_sol['High'],
        "low": last_row_sol['Low'],
        "close": last_row_sol['Close'],
        "volume": last_row_sol['Volume'],
        "edit_count": last_row_sol_sentiment['edit_count'],
        "sentiment": last_row_sol_sentiment['sentiment'],
        "neg_sentiment": last_row_sol_sentiment['neg_sentiment']
    }
    return latest_data

# %%
# Fetch and preprocess new data
latest_data = fetch_latest_data()
latest_df = pd.DataFrame([latest_data])
latest_df
# Out:
#          open        high         low       close      volume  edit_count  \
# 0  163.218658  165.460602  161.855103  165.418304  1816263936         2.9
#
#    sentiment  neg_sentiment
# 0   -0.15647       0.575079

# %%
latest_probabilities = model.predict_proba(latest_df)
# Out:
# c:\Users\SUBRAT\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function to plot probabilities
def plot_probabilities(probabilities):
    labels = ['Decrease', 'Increase']
    values = probabilities[0]

    fig, ax = plt.subplots()
    ax.barh(labels, values, color=['red', 'green'])
    ax.set_xlim(0, 1)
    ax.set_xlabel('Probability')
    ax.set_title('Probability of Bitcoin Price Change')

    for index, value in enumerate(values):
        ax.text(value, index, f'{value:.2f}', va='center')

    plt.show()

# %%
# Fetch the combined data
latest_data = fetch_latest_data()

# Create a DataFrame with the latest data
latest_df = pd.DataFrame([latest_data])

# Standardize the latest data
latest_X_scaled = scaler.transform(latest_df[features])

# Predict the probabilities
latest_probabilities = model.predict_proba(latest_X_scaled)

# Plot the probabilities
plot_probabilities(latest_probabilities)

# %%
print(f"Probability of price decrease: {latest_probabilities[0][0]:.2f}")
print(f"Probability of price increase: {latest_probabilities[0][1]:.2f}")
# Out:
# Probability of price decrease: 0.66
# Probability of price increase: 0.34

# %%
import pickle 
with open('sol_prob.pkl', 'wb') as f:
    pickle.dump(model, f)
